# %%
from src.primitives.probe import Probe
# Out:
# /home/abhirath/projects/Metronome/src/primitives/probe.py:17: SyntaxWarning: invalid escape sequence '\ '
#   """# tower_of_hanoi_3x3 = TowerOfHanoi(3, 3)

# %%
reward_samples = Probe.load_reward_samples("results/morpion_solitaire_5d_kde/")

# %%
Probe.kernel_density_plots_from_rewards(reward_samples, show=True)
